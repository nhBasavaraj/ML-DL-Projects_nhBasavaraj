# %% [markdown]
# ## Amazon Stock Price (27-5-1997 : 05-04-2023)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = pd.read_csv(r"/content/drive/MyDrive/Colab Notebooks/Amazon Stock Data/AMZN.csv")
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
data.isnull().any()
# Out:
# Date         False
# Open         False
# High         False
# Low          False
# Close        False
# Adj Close    False
# Volume       False
# dtype: bool

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  6516.000000  6516.000000  6516.000000  6516.000000  6516.000000
# mean     31.611626    31.991995    31.193432    31.599740    31.599740
# std      48.095343    48.659651    47.464476    48.060258    48.060258
# min       0.070313     0.072396     0.065625     0.069792     0.069792
# 25%       1.998875     2.028500     1.964750     2.001250     2.001250
# 50%       6.456750     6.535500     6.353250     6.444250     6.444250
# 75%      38.451375    38.688000    38.203001    38.464625    38.464625
# max     187.199997   188.654007   184.839493   186.570496   186.570496
#
#              Volume
# count  6.516000e+03
# mean   1.425338e+08
# std    1.401619e+08
# min    9.744000e+06
# 25%    6.888182e+07
# 50%    1.059050e+08
# 75%    1.607700e+08
# max    2.086584e+09

# %%
duplicate_data=data.duplicated()

# %%
duplicate_data.sum()
# Out:
# 0

# %%
numerical_columns = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# Plot histograms for numerical features
data[numerical_columns].hist(bins=10, figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
# Create box plots for numerical features
data[numerical_columns].boxplot(figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
# Create density plots for numerical features
data[numerical_columns].plot(kind='density', subplots=True, layout=(2, 3), sharex=False, figsize=(10, 6))
plt.tight_layout()
plt.show()

# %%
# Calculate 20-day simple moving average (SMA)
data['SMA_20'] = data['Close'].rolling(window=20).mean()
data.sample(20)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 569   1999-08-18    2.878125    2.937500    2.812500    2.828125    2.828125
# 1920  2005-01-03    2.247500    2.272000    2.210500    2.226000    2.226000
# 6040  2021-05-17  162.296494  164.637497  161.729507  163.519501  163.519501
# 5522  2019-04-26   96.449997   97.550003   94.900002   97.531502   97.531502
# 2898  2008-11-19    1.898500    1.950000    1.787500    1.792000    1.792000
# 686   2000-02-03    4.056250    4.296875    3.868750    4.209375    4.209375
# 471   1999-03-30    3.800000    4.237500    3.788281    4.117188    4.117188
# 826   2000-08-23    1.818750    1.975000    1.750000    1.940625    1.940625
# 5661  2019-11-12   88.733002   89.310997   88.595497   88.900002   88.900002
# 340   1998-09-21    0.633333    0.723958    0.633333    0.712500    0.712500
# 590   1999-09-17    3.281250    3.300000    3.137500    3.190625    3.190625
# ...

# %%
data.tail(20)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 6496  2023-03-09   93.680000   96.209999   92.180000   92.250000   92.250000
# 6497  2023-03-10   92.669998   93.570000   90.250000   90.730003   90.730003
# 6498  2023-03-13   89.970001   94.019997   88.120003   92.430000   92.430000
# 6499  2023-03-14   93.830002   95.070000   92.709999   94.879997   94.879997
# 6500  2023-03-15   93.220001   96.669998   93.070000   96.199997   96.199997
# 6501  2023-03-16   95.750000  100.989998   95.610001  100.040001  100.040001
# 6502  2023-03-17   99.790001  100.660004   97.459999   98.949997   98.949997
# 6503  2023-03-20   98.410004   98.480003   95.699997   97.709999   97.709999
# 6504  2023-03-21   98.139999  100.849998   98.000000  100.610001  100.610001
# 6505  2023-03-22  100.449997  102.099998   98.610001   98.699997   98.699997
# 6506  2023-03-23  100.430000  101.059998   97.620003   98.709999   98.709999
# ...

# %%
# Calculate 50-day simple moving average (SMA)
data['SMA_50'] = data['Close'].rolling(window=50).mean()

# %%
data
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume     SMA_20   SMA_50
# ...

# %%
data.drop(["SMA_20","SMA_50"], axis=1, inplace = True)

# %%
df1=data

# %%
df1
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1     1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2     1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3     1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4     1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...          ...         ...         ...         ...         ...         ...
# 6511  2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512  2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513  2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514  2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515  2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# ...

# %%
df1.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df1["Date"]=pd.to_datetime(df1['Date'])

# %%
df1.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# dtype: object

# %%
df1.shape
# Out:
# (6516, 7)

# %%
# Plotting the stock data
plt.figure(figsize=(12, 6))
plt.plot(df1['Date'], data['Close'])
plt.xlabel('Date')
plt.ylabel('Close Stock Value')
plt.title('Stock Price')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
px.line(df1, x="Date", y="Close")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    1997-05-15    0.121875    0.125000    0.096354    0.097917    0.097917
# 1    1997-05-16    0.098438    0.098958    0.085417    0.086458    0.086458
# 2    1997-05-19    0.088021    0.088542    0.081250    0.085417    0.085417
# 3    1997-05-20    0.086458    0.087500    0.081771    0.081771    0.081771
# 4    1997-05-21    0.081771    0.082292    0.068750    0.071354    0.071354
# ...         ...         ...         ...         ...         ...         ...
# 6511 2023-03-30  101.550003  103.040001  101.010002  102.000000  102.000000
# 6512 2023-03-31  102.160004  103.489998  101.949997  103.290001  103.290001
# 6513 2023-04-03  102.300003  103.290001  101.430000  102.410004  102.410004
# 6514 2023-04-04  102.750000  104.199997  102.110001  103.949997  103.949997
# 6515 2023-04-05  103.910004  103.910004  100.750000  101.099998  101.099998
#
#           Volume
# 0     1443120000
# 1      294000000
# ...

# %%
X = df1.drop(['Close','Adj Close'], axis=1)
X
# Out:
#            Date        Open        High         Low      Volume
# 0    1997-05-15    0.121875    0.125000    0.096354  1443120000
# 1    1997-05-16    0.098438    0.098958    0.085417   294000000
# 2    1997-05-19    0.088021    0.088542    0.081250   122136000
# 3    1997-05-20    0.086458    0.087500    0.081771   109344000
# 4    1997-05-21    0.081771    0.082292    0.068750   377064000
# ...         ...         ...         ...         ...         ...
# 6511 2023-03-30  101.550003  103.040001  101.010002    53633400
# 6512 2023-03-31  102.160004  103.489998  101.949997    56704300
# 6513 2023-04-03  102.300003  103.290001  101.430000    41135700
# 6514 2023-04-04  102.750000  104.199997  102.110001    48662500
# 6515 2023-04-05  103.910004  103.910004  100.750000    45103000
#
# [6516 rows x 5 columns]

# %%
y = df1[['Close', 'Adj Close']]

# %%
y
# Out:
#            Close   Adj Close
# 0       0.097917    0.097917
# 1       0.086458    0.086458
# 2       0.085417    0.085417
# 3       0.081771    0.081771
# 4       0.071354    0.071354
# ...          ...         ...
# 6511  102.000000  102.000000
# 6512  103.290001  103.290001
# 6513  102.410004  102.410004
# 6514  103.949997  103.949997
# 6515  101.099998  101.099998
#
# [6516 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr
#lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Drop the 'Date' column from X_train
X_train = X_train.drop('Date', axis=1)
X_test = X_test.drop("Date", axis=1)
# Convert y_train to a NumPy array
# y_train_array = y_train['Close'].values

# %%
X_train
# Out:
#            Open       High        Low     Volume
# 3529   9.850000   9.850000   9.650000   59454000
# 3182   6.600500   6.616000   6.440000  220604000
# 5137  49.840500  50.422001  49.619999   81346000
# 2181   2.197500   2.216000   2.183000  112620000
# 2572   3.927500   4.000000   3.894500  161186000
# ...         ...        ...        ...        ...
# 3772  11.195500  11.454000  11.097500   92968000
# 5191  59.117500  59.200001  58.375000   53768000
# 5226  74.250000  75.174500  73.945999  126088000
# 5390  89.750000  89.752502  86.711502  128744000
# 860    1.396875   1.512500   1.381250  157794000
#
# [4561 rows x 4 columns]

# %%
model=lr.fit(X_train, y_train)

# %%
model.score(X_test, y_test)
# Out:
# 0.9999234559932573

# %% [markdown]
# Use K Fold cross validation to measure accuracy of our LinearRegression model

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

y_close = y['Close']
y_adj_close = y['Adj Close']

X = X.drop('Date', axis=1)

cv=ShuffleSplit(n_splits=10, test_size=0.2)
score_close=cross_val_score(LinearRegression(),X,y_close, cv=cv)
score_adj_close=cross_val_score(LinearRegression(), X, y_adj_close, cv=cv)

# %%
print("Mean Accuracy (Close):", score_close.mean())
print("Mean Accuracy (Adj Close):", score_adj_close.mean())
# Out:
# Mean Accuracy (Close): 0.9999214987860983
# Mean Accuracy (Adj Close): 0.999921991349645

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# Create separate models for each target variable
models = {
    'Close': [
        ('Linear Regression', LinearRegression(), {}),
        ('Decision Tree', DecisionTreeRegressor(), {'max_depth': [None, 10, 20]}),
        ('Random Forest', RandomForestRegressor(), {'n_estimators': [50, 100, 200]}),
        ('SVM', SVR(), {'C': [0.1, 1.0, 10.0]}),
    ],
    'Adj Close': [
        ('Linear Regression', LinearRegression(), {}),
        ('Decision Tree', DecisionTreeRegressor(), {'max_depth': [None, 10, 20]}),
        ('Random Forest', RandomForestRegressor(), {'n_estimators': [50, 100, 200]}),
        ('SVM', SVR(), {'C': [0.1, 1.0, 10.0]}),
    ]
}

# Perform GridSearchCV for each target variable and model
best_scores = {}
for target_var, models_list in models.items():
    for name, model, params in models_list:
        grid_search = GridSearchCV(model, param_grid=params, cv=5, n_jobs=-1)
        grid_search.fit(X_train, y_train[target_var])
        best_scores[(target_var, name)] = grid_search.best_score_

# Print the best scores for each target variable and model
for (target_var, name), score in best_scores.items():
    print(f"{target_var} - {name} - Best Score: {score:.4f}")
# Out:
# Close - Linear Regression - Best Score: 0.9999
# Close - Decision Tree - Best Score: 0.9997
# Close - Random Forest - Best Score: 0.9998
# Close - SVM - Best Score: -0.0665
# Adj Close - Linear Regression - Best Score: 0.9999
# Adj Close - Decision Tree - Best Score: 0.9997
# Adj Close - Random Forest - Best Score: 0.9998
# Adj Close - SVM - Best Score: -0.0665

# %%
import joblib
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# Create separate models for each target variable
models = {
    'Close': [
        ('Linear Regression', LinearRegression(), {}),
        ('Decision Tree', DecisionTreeRegressor(max_depth=10), {}),
        ('Random Forest', RandomForestRegressor(n_estimators=100), {}),
        # SVM does not perform well for this problem, so we'll skip saving it
    ],
    'Adj Close': [
        ('Linear Regression', LinearRegression(), {}),
        ('Decision Tree', DecisionTreeRegressor(max_depth=10), {}),
        ('Random Forest', RandomForestRegressor(n_estimators=100), {}),
        # SVM does not perform well for this problem, so we'll skip saving it
    ]
}

# Train and save the best models
for target_var, models_list in models.items():
    for name, model, params in models_list:
        model.fit(X_train, y_train[target_var])
        joblib.dump(model, f"{target_var} - {name}.pkl")
